# %% [markdown]
# ## Langgraph Aircfrat Maintenance Report Agent
#
# You are an expert writer tasked with writing a high level outline of aircraft maintenance research report.  Write such an outline for user provided topic.  Give an outline of the essay along with notes and instructions for the sections
#
# ##### Note: Go to JupyterLab terminal and execute following command before getting started
# <pre>
#     uv add langgraph
# </pre>

# %%
# set the working directory for the project
# %cd /home/vcap/app/cf-jupyterlab-workshop

# %%
#set up your-tavily-key
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List, Optional
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
import os, sys
import requests
import json
from openai import OpenAI
import httpx
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI
from langchain.agents import tool
from langchain.agents import initialize_agent, AgentType, load_tools
from langchain_core.tools import Tool
from pydantic import BaseModel, ValidationError
#from langchain_core.pydantic_v1 import BaseModel
from langchain.tools import tool
from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser
from langchain.prompts import PromptTemplate
from langgraph.checkpoint.sqlite import SqliteSaver
from tavily import TavilyClient
from langchain_community.tools.tavily_search import TavilySearchResults
from IPython.display import Image
import re
import json
from typing import Dict, Any
from cfenv import AppEnv
from tanzu_utils import CFGenAIService

# connect to tavily search tool - use your tavily api key
os.environ['TAVILY_API_KEY']="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"
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])
#tool = TavilySearchResults(max_results=2)

#define agent state
class AgentState(TypedDict):
    task: str
    lnode: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    queries: List[str]
    revision_number: int
    max_revisions: int
    count: Annotated[int, operator.add]


#define and configure the model
# Load CF environment
env = AppEnv()
# configure model
httpx_client = httpx.Client(http2=True, verify=False, timeout=10.0)
# Get bound service "gen-ai-qwen3-ultra"
chat_service = CFGenAIService("tanzu-gpt-oss-120b")
# List available models
models = chat_service.list_models()
for m in models:
    print(f"- {m['name']} (capabilities: {', '.join(m['capabilities'])})")

# construct chat_credentials
chat_credentials = {
    "api_base": chat_service.api_base + "/openai/v1",
    "api_key": chat_service.api_key,
    "model_name": models[0]["name"]
}

# Initialize LLM with credentials from cfenv
model = ChatOpenAI(
    temperature=0.9,
    model=chat_credentials["model_name"],
    base_url=chat_credentials["api_base"],
    api_key=chat_credentials["api_key"],
    http_client=httpx_client
)

#define prompts
PLAN_PROMPT = """
You are an expert writer tasked with writing a high level outline of an eassy. \
Write such an outline for the user provided topic. Give an outline of eassy along \
with any relevant notes or instructions for the sections.
"""

WRITER_PROMPT = """
You are an eassy assistant tasked with writing excellent 5-paragraph eassys. \
Generate the best eassy possible for the user's request and the initial outline. \
If the user provides critique, respond with a revised version of ypur previous attempts. \

--------

{content}"""

REFLECTION_PROMPT = """
You are a teacher grading an eassy submission. \
Generate critique and recommendations for the user's submission. \
Provide detailed recommendations, including requests for length, depth, style, etc.
"""

RESEARCH_PLAN_PROMPT = """
You are a researcher charged with providing information that can \
be used when writing the following eassy. Generate a list of search queries that will gather \
any relevant information. Only generate 3 queries max
"""

RESEARCH_CRITIQUE_PROMPT = """
You are a researcher charged with providing information that can \
be used when making any requested revisions (as oulined below). \
Generate a list of search queries that will gather any relevant information. \
Only generate 3 queries max.
"""
    
def extract_json(text):
    # Remove unwanted tags like <think> and <speak>
    cleaned_text = re.sub(r'<\/?[\w\d]+>', '', text).strip()

    # Now try to extract the JSON part using regex
    match = re.search(r'\{.*\}', cleaned_text, re.DOTALL)
    if not match:
        raise ValueError("No JSON object found in response")
    return json.loads(match.group(0))

def normalize_to_queries(output: str) -> Dict[str, Any]:
    """
    Normalize LLM output into a dict matching the Queries schema.
    Always returns: {"queries": [...]}.
    Also logs the result as clean JSON.
    """

    # Remove <think>...</think> blocks if present
    output = re.sub(r"<think>.*?</think>", "", output, flags=re.DOTALL).strip()

    data: Dict[str, Any]

    # Try strict JSON parse first
    try:
        parsed = json.loads(output)
        if isinstance(parsed, dict) and "queries" in parsed:
            data = parsed
        elif isinstance(parsed, list):
            data = {"queries": parsed}
        else:
            raise ValueError("Invalid schema")
    except Exception:
        # Fallback: treat as markdown/bullet/numbered list
        lines = [
            re.sub(r'^\s*[\d\-\*\.\)]*\s*', '', line).strip(' *"`')
            for line in output.splitlines() if line.strip()
        ]
        # Deduplicate while preserving order
        seen = set()
        unique_lines = [q for q in lines if not (q in seen or seen.add(q))]
        data = {"queries": unique_lines}

    return data
    
class Queries(BaseModel):
    queries: List[str]

#implement nodes
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT),
        HumanMessage(content=state["task"])
    ]
    response = model.invoke(messages)
    response_content = response.content if hasattr(response, 'content') else str(response)

    # Remove <think>...</think> blocks completely
    response_content = re.sub(r"<think>.*?</think>", "", response_content, flags=re.DOTALL).strip()
    return {"plan": response_content}
    
def research_plan_node(state: dict):
    """
    Generates a research plan using a Qwen model and Tavily search.
    Works without Pydantic.
    """
    # Invoke Qwen model (plain text output)
    raw_response = model.invoke(
        [
            SystemMessage(content=RESEARCH_PLAN_PROMPT),
            HumanMessage(content=state["task"]),
        ]
    )
    response_content = getattr(raw_response, "content", str(raw_response))

    # Remove <think>...</think> if present
    response_content = re.sub(r"<think>.*?</think>", "", response_content, flags=re.DOTALL).strip()

    # Normalize into a list of queries (handle bullets, numbers, etc.)
    lines = [
        re.sub(r'^\s*[\d\-\*\.\)]*\s*', '', line).strip(' *"`')
        for line in response_content.splitlines()
        if line.strip()
    ]
    # Deduplicate
    seen = set()
    queries_list = [q for q in lines if not (q in seen or seen.add(q))]

    # Initialize content
    content = state.get("content", [])

    # Perform Tavily searches
    for q in queries_list:
        try:
            response = tavily.search(query=q, max_results=2)
            for r in response.get("results", []):
                content_piece = r.get("content", "")
                if content_piece:
                    content.append(str(content_piece))
        except Exception as e:
            print(f"Search failed for query '{q}': {e}")

    return {
        "content": content,
    }
def generation_node(state: AgentState):
    content = "\n\n".join(["content"] or [])
    user_message = HumanMessage(content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(content=WRITER_PROMPT.format(content=content)),
        user_message,
    ]
    response = model.invoke(messages)
    response_content = response.content if hasattr(response, 'content') else str(response)

    # Remove <think>...</think> blocks completely
    response_content = re.sub(r"<think>.*?</think>", "", response_content, flags=re.DOTALL).strip()
    return {
        "draft": response_content,
        "revision_number": state.get("revision_number", 1) + 1,
    }
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT),
        HumanMessage(content=state['draft']),
    ]
    response = model.invoke(messages)
    response_content = response.content if hasattr(response, 'content') else str(response)

    # Remove <think>...</think> blocks completely
    response_content = re.sub(r"<think>.*?</think>", "", response_content, flags=re.DOTALL).strip()

    return {"critique": response_content}

def research_critique_node(state: AgentState):
    """
    Generates a research plan using a Qwen model and Tavily search.
    Works without Pydantic.
    """
    # Invoke Qwen model (plain text output)
    raw_response = model.invoke(
        [
            SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
            HumanMessage(content=state["critique"]),
        ]
    )
    response_content = getattr(raw_response, "content", str(raw_response))

    # Remove <think>...</think> if present
    response_content = re.sub(r"<think>.*?</think>", "", response_content, flags=re.DOTALL).strip()

    # Normalize into a list of queries (handle bullets, numbers, etc.)
    lines = [
        re.sub(r'^\s*[\d\-\*\.\)]*\s*', '', line).strip(' *"`')
        for line in response_content.splitlines()
        if line.strip()
    ]
    # Deduplicate
    seen = set()
    queries_list = [q for q in lines if not (q in seen or seen.add(q))]

    # Initialize content
    content = state.get("content", [])

    # Perform Tavily searches
    for q in queries_list:
        try:
            response = tavily.search(query=q, max_results=2)
            for r in response.get("results", []):
                content_piece = r.get("content", "")
                if content_piece:
                    content.append(str(content_piece))
        except Exception as e:
            print(f"Search failed for query '{q}': {e}")

    return {
        "content": content,
    }

def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"


#build graph
builder = StateGraph(AgentState)
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

#set entry point
builder.set_entry_point("planner")

#define conditional edges
builder.add_conditional_edges(
    "generate", 
    should_continue, 
    {END: END, "reflect": "reflect"}
)

#define edges
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")



#print graph
#Image(graph.get_graph().draw_png())


thread = {"configurable": {"thread_id": "1"}}
with SqliteSaver.from_conn_string(":memory:") as checkpointer:
    graph = builder.compile(checkpointer=checkpointer)
    for s in graph.stream({
        'task': "Create a structured troubleshooting document based on the following aircraft equipment issues: The reported hydraulic‑leak issue is with **Landing Gear B",
        "max_revisions": 2,
        "revision_number": 1,
    }, thread):
        print(s)
# Out:
# /home/vcap/app/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'genai-proxy.sys.tas-ndc.kuhn-labs.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# - openai/gpt-oss-120b (capabilities: CHAT, TOOLS)
# {'planner': {'plan': '**Essay Outline – “Developing a Structured Troubleshooting Document for a Hydraulic‑Leak in Landing‑Gear\u202fB”**  \n\n---\n\n### 1. Introduction  \n- **Purpose of the essay** – Explain why a systematic troubleshooting document is essential for aircraft hydraulic‑leak problems, especially on critical systems such as Landing‑Gear\u202fB.  \n- **Scope** – Limited to the hydraulic‑leak symptom; excludes other gear‑related failures (actuator, steering, etc.).  \n- **Thesis statement** – A well‑structured troubleshooting guide, built on safety, root‑cause analysis, and clear documentation, reduces aircraft downtime, improves safety, and ensures regulatory compliance.\n\n### 2. Background  \n- **Landing‑Gear\u202fB overview**  \n  - Position on the airframe, primary functions, and hydraulic dependencies.  \n  - Typical hydraulic pressure range and fluid type.  \n- **Hydraulic‑leak implications**  \n  - Effect on gear extension/retraction, braking, and aircraft weight‑on‑wheels (WOW) sensors.  \n  - Potential safety hazards (fluid fire, loss of control).  \n- **Regulatory framework** – FAR/CS/ATA 32, OEM maintenance manuals, and company SOPs that dictate leak reporting and corrective action.\n\n### 3. Importance of a Structured Troubleshooting Approach  \n- **Consistency** – Uniform steps across technicians, shift changes, and geographic locations.  \n- **Traceability** – Enables audit trails for maintenance actions and root‑cause verification.  \n- **Efficiency** – Reduces unnecessary part removal, test cycles, and aircraft ground time.  \n- **Risk mitigation** – Embeds safety precautions and hazard assessments at each stage.\n\n### 4. Core Components of the Troubleshooting Document  \n| Component | Description | Reason for Inclusion |\n|-----------|-------------|----------------------|\n| **Safety Precautions** | PPE, hydraulic fluid handling, grounding, fire‑suppression readiness. | Prevents injury and secondary damage. |\n| **Symptom Description** | Exact leak characteristics (location, rate, fluid type). | Sets baseline for diagnosis. |\n| **Possible Causes** | Fault tree or cause‑effect matrix (e.g., seal failure, hose damage, over‑pressure). | Guides logical elimination. |\n| **Diagnostic Tools & Equipment** | Pressure gauges, UV dye kits, borescopes, leak‑detector sprays, torque wrenches. | Ensures technicians have the right resources. |\n| **Step‑by‑Step Procedure** | Sequential actions, decision points, and “go/no‑go” criteria. | Provides clear, repeatable workflow. |\n| **Verification & Test** | Post‑repair functional tests (gear cycle, pressure check, leak verification). | Confirms issue resolution. |\n| **Documentation & Reporting** | Forms, log‑book entries, discrepancy codes, and ASRS reporting if needed. | Meets regulatory and company record‑keeping. |\n| **References** | OEM manual chapters, service bulletins, regulatory notices. | Supplies authoritative guidance. |\n\n### 5. Detailed Outline of the Troubleshooting Procedure (High‑Level Flow)  \n1. **Initial Assessment**  \n   - Visual inspection of gear bay and hydraulic lines.  \n   - Record leak rate (drip count per minute) and fluid characteristics.  \n2. **Safety Setup**  \n   - Apply lock‑out/tag‑out (LOTO) on the hydraulic system.  \n   - Install fire‑extinguishers and spill containment.  \n3. **Preliminary Tests**  \n   - Measure system pressure with calibrated gauge.  \n   - Perform a “pressure hold” test to isolate the leak source.  \n4. **Isolation of the Leak**  \n   - Use UV dye injection and UV light to pinpoint leak.  \n   - Apply leak‑detecting spray on suspect joints.  \n5. **Component Evaluation**  \n   - Check seals, O‑rings, and hydraulic hoses for wear or damage.  \n   - Inspect actuator pistons and rod ends for corrosion or scoring.  \n6. **Repair/Replacement Decision Tree**  \n   - If seal defect → replace seal.  \n   - If hose damage → replace hose assembly.  \n   - If over‑pressure → verify pressure regulator/relief val ...
# Search failed for query '': Query is missing.
# Search failed for query '|------|-------------|': Query is invalid.
# Search failed for query '|----------|----------------------|------------------|': Query is invalid.
# Search failed for query '|------|--------|--------------------|----------------------|': Query is invalid.
# Search failed for query '|--------|---------------|----------------|--------------------|': Query is invalid.
# Search failed for query '|-----------|-------------|---------------|': Query is invalid.
# Search failed for query '|---|------|': Query is invalid.
# {'research_plan': {'content': ['*   Description The yt-remote-session-app cookie is used by YouTube to store user preferences and information about the interface of the embedded YouTube video player. *   Understanding the Aircraft Hydraulic System *   Common Problems in Aircraft Hydraulic Systems *   Aircraft Hydraulic System Troubleshooting Tips Understanding the Aircraft Hydraulic System Common Problems in Aircraft Hydraulic Systems Recognizing common problems is the first step to troubleshooting an aircraft’s hydraulic system. Aircraft Hydraulic System Troubleshooting Tips The most common culprits behind aircraft hydraulic system failures are contamination (air, water, or particles in the fluid), extreme temperatures, component wear and tear, and leaks in the system. Troubleshooting aircraft hydraulic systems begins with understanding how they work and the common symptoms of problems.', "The first step is to map the helicopter's hydraulic system and components by measuring the hydraulic pressure temperature input and return on the hydraulic", 'It very much depends on where the leqk is and how severe. The good news is that the gear does not need hydraulic power to lower, only for it to be raised.', 'Follow up on the landing gear hydraulic leak. I found a fracture in the body of the dump valve located in the automatic gear extension system.', 'commercial aircraft platforms, such as the Airbus A320, the Boeing 737 Family and the Boeing 777, as well as in military platform, such as', 'any future Boeing airplane will include such a system? Mr ... least 2 knots per second, with the flaps and landing gear in any normal position,', '# Democracy only works if we do. At Issue One, we’re building bipartisan power to strengthen the foundations of American democracy — because fixing our broken political system starts with all of us. Working to uphold the rule of law, protect our institutions, and keep power where it belongs — in a government of, by, and for the people. Learn about the related work of our National Council on Election Integrity and our Faces of Democracy campaign. Issue One is at the forefront of bipartisan reform, working with over 200 former members of Congress and political appointees, technologists, and election officials from across the political spectrum. ReFormers Caucus   Faces of Democracy   Council for Responsible Social Media   The Council for American Democracy', 'Issue One is an American nonprofit organization that seeks to reduce the role of money in politics. It aims to increase public awareness of what it views as', 'Define Item Description. the information presented in this column indicates the specific item that LPHA is authorized to acquire.', 'Note: The Item Description belongs to the item and will remain with it even when moved between boards or converted to a subitem or vice versa.', 'Hydraulic systems are vital to modern aviation, providing the power needed for essential aircraft operations such as landing gear, flight control surfaces, and braking systems. By the 1930s, hydraulic systems were integrated into military aircraft, providing power to retract landing gear and operate control surfaces. These characteristics make hydraulic systems the preferred solution for powering key aircraft functions such as **landing gear extension/retraction, flight controls, spoilers, and brakes**. * **Operation**: The standby system is automatically or manually activated, providing hydraulic power to ensure the safety of the aircraft during critical moments, such as landing. * Hydraulic systems operate at very high pressures, typically around **3000 psi** in the Boeing 737, providing the force needed to control heavy aircraft components with precision.', 'Hydraulic Retraction system\u200b\u200b A hydraulic system for retracting and extending a landing gear normally takes its power from engine driven pumps, alternative', 'Fluid Accumulation: Puddles, drips, or wet spots around your hydraulic equipment are the most  ...
# {'generate': {'draft': '**Developing a Structured Troubleshooting Document for a Hydraulic‑Leak in Landing‑Gear\u202fB**\n\nThe reliability of an aircraft’s hydraulic system is a cornerstone of flight safety, and any leak in a critical component such as Landing‑Gear\u202fB can quickly escalate from a minor inconvenience to a serious hazard. Because the gear‑extension and retraction mechanisms, weight‑on‑wheels (WOW) sensors, and brake actuators all depend on a clean, pressurized hydraulic circuit, a leak not only threatens the mechanical function of the gear but also introduces fire‑risk, loss of control, and costly aircraft downtime. A well‑crafted troubleshooting document therefore serves three essential purposes: it guarantees a consistent, repeatable diagnostic workflow across technicians and shifts; it creates a clear audit trail that satisfies regulatory and corporate compliance requirements; and it streamlines the repair process, thereby reducing mean‑time‑to‑repair (MTTR) and preserving flight schedules. In short, a systematic guide for the Landing‑Gear\u202fB hydraulic leak transforms a potentially chaotic reaction into a controlled, safety‑first resolution.\n\nLanding‑Gear\u202fB is typically situated on the right side of the fuselage and operates through a dedicated high‑pressure hydraulic loop—often in the range of 3000 to 3500\u202fpsi, using a phosphate‑ester based fluid. The gear’s hydraulic actuator extends and retracts the strut, while associated sensors feed position data to the flight‑deck. A leak can manifest as dripping fluid in the gear bay, a drop in system pressure, or erratic sensor readings. Beyond the immediate mechanical effects, escaped fluid can accumulate on hot components, creating a fire source, and can contaminate nearby electrical wiring, precipitating short circuits. The regulatory environment—spanning FAA Part\u202f43, EASA Part‑M, ATA 32, and OEM maintenance manuals—mandates prompt reporting, thorough documentation, and verification of any hydraulic anomaly before the aircraft is returned to service.\n\nThe value of a structured troubleshooting approach lies in its ability to embed safety, traceability, and efficiency into every step of the diagnostic cycle. Consistency is achieved by presenting technicians with a uniform set of actions, decision points, and “go/no‑go” criteria, regardless of their location or shift timing. Traceability is ensured through detailed log‑book entries, discrepancy codes, and required sign‑offs, creating an auditable record that regulators and management can review. Efficiency gains emerge from a logical elimination process that prioritizes low‑cost, non‑intrusive tests—such as visual inspections, pressure‑hold checks, and UV‑dye localization—before resorting to component removal. Finally, risk mitigation is built directly into the document: each phase begins with explicit safety precautions (personal protective equipment, lock‑out/tag‑out, fire‑suppression readiness) and ends with verification steps that confirm the leak has been fully resolved before the aircraft is cleared for flight.\n\nThe core of the troubleshooting document is a series of interlocking components that together form a complete diagnostic protocol. First, a **Safety Precautions** section enumerates required PPE, grounding procedures, and spill‑containment measures, ensuring that technicians never approach the leak without adequate protection. Second, a **Symptom Description** table captures the exact nature of the leak—its location, rate (e.g., drips per minute), fluid color, and any associated sensor alerts—providing a baseline for analysis. Third, a **Possible Causes** matrix (often presented as a fault‑tree) lists probable origins such as seal degradation, hose abrasion, over‑pressure conditions, or actuator piston scoring, allowing technicians to follow a logical elimination path. Fourth, a **Diagnostic Tools & Equipment** checklist specifies calibrated pressure gauges, UV‑dye kits, bor ...
# {'reflect': {'critique': '**Overall Assessment**\n\nYour essay presents a clear, well‑structured argument for why a formal troubleshooting document is essential when dealing with a hydraulic leak in Landing‑Gear\u202fB. You successfully weave together technical details, regulatory context, safety considerations, and operational benefits, demonstrating a solid grasp of both the engineering and procedural aspects of the problem. The piece reads like a professional briefing that could be used to convince management or to introduce a new maintenance process.\n\n**Strengths**\n\n| Area | What you did well |\n|------|-------------------|\n| **Clarity of Purpose** | You opened with a concise statement of the three core reasons a structured document is needed (consistency, traceability, efficiency) and kept returning to those themes throughout. |\n| **Technical Accuracy** | You correctly identified the typical pressure range, fluid type, and the interaction of the gear‑actuator, WOW sensors, and brake system. |\n| **Regulatory Awareness** | You referenced the relevant FAA, EASA, and ATA standards, showing that you understand the compliance landscape. |\n| **Logical Organization** | The “core components” section (Safety, Symptom Description, Possible Causes, etc.) is laid out in a logical, step‑by‑step fashion that mirrors real‑world troubleshooting guides. |\n| **Risk‑Mitigation Emphasis** | Each phase is linked to explicit safety measures, which is exactly what a safety‑critical document must do. |\n| **Future‑Proofing** | You mention periodic review, service‑bulletin updates, and integration with training—good forward‑looking thinking. |\n\n**Areas for Improvement**\n\n| Issue | Why it matters | Suggested action |\n|-------|----------------|------------------|\n| **Length & Depth of Certain Sections** | The “Possible Causes” matrix is mentioned but not illustrated. Readers benefit from a concrete example (e.g., a fault‑tree diagram or tabular list with probability ratings). | Add a brief sample matrix (3‑5 likely root causes, their symptoms, and recommended first‑level tests). |\n| **Quantitative Evidence** | Statements such as “reduces MTTR” are persuasive, but without numbers they remain anecdotal. | Include a KPI comparison (e.g., “average MTTR dropped from 12\u202fhrs to 7\u202fhrs after implementation of the guide on a similar fleet”). |\n| **Citation & Source Credibility** | You reference standards (FAA Part\u202f43, EASA Part‑M, ATA 32) but do not cite specific sections or provide a bibliography. | Add footnotes or an end‑reference list showing the exact paragraphs or bullet points you are drawing from. |\n| **Style Consistency** | The essay occasionally shifts between a formal briefing tone and a more conversational one (“In short, a systematic guide…”). Consistency strengthens authority. | Choose a single voice (preferably formal/technical) and edit the few informal phrases to match. |\n| **Visual Aids** | A troubleshooting guide is inherently visual (flowcharts, checklists, tables). The text describes these elements but does not show them. | Insert at least one illustrative flowchart (e.g., “Pressure‑Hold Test → UV‑Dye Positive → Component Replacement”) or a sample checklist table. |\n| **Depth of Safety Precautions** | PPE and LOTO are mentioned, but you could expand on fire‑suppression readiness (type of extinguishant, proximity of fire blankets, etc.). | Provide a short bulleted list of the exact PPE (e.g., fire‑resistant coveralls, chemical‑resistant gloves, safety glasses, hearing protection) and fire‑suppression equipment (e.g., ABC dry‑chemical extinguisher, fire‑retardant blankets). |\n| **Integration with Digital Platforms** | You note “readily integrated into digital maintenance platforms” but do not explain how. | Briefly describe the data exchange format (e.g., XML/ATA‑iSpec) or the workflow in a maintenance software (e.g., SAP PM, AMOS) and any benefits (real‑time status, auto‑population of discrepancy forms). ...
# {'research_critique': {'content': ['*   Description The yt-remote-session-app cookie is used by YouTube to store user preferences and information about the interface of the embedded YouTube video player. *   Understanding the Aircraft Hydraulic System *   Common Problems in Aircraft Hydraulic Systems *   Aircraft Hydraulic System Troubleshooting Tips Understanding the Aircraft Hydraulic System Common Problems in Aircraft Hydraulic Systems Recognizing common problems is the first step to troubleshooting an aircraft’s hydraulic system. Aircraft Hydraulic System Troubleshooting Tips The most common culprits behind aircraft hydraulic system failures are contamination (air, water, or particles in the fluid), extreme temperatures, component wear and tear, and leaks in the system. Troubleshooting aircraft hydraulic systems begins with understanding how they work and the common symptoms of problems.', "The first step is to map the helicopter's hydraulic system and components by measuring the hydraulic pressure temperature input and return on the hydraulic", 'It very much depends on where the leqk is and how severe. The good news is that the gear does not need hydraulic power to lower, only for it to be raised.', 'Follow up on the landing gear hydraulic leak. I found a fracture in the body of the dump valve located in the automatic gear extension system.', 'commercial aircraft platforms, such as the Airbus A320, the Boeing 737 Family and the Boeing 777, as well as in military platform, such as', 'any future Boeing airplane will include such a system? Mr ... least 2 knots per second, with the flaps and landing gear in any normal position,', '# Democracy only works if we do. At Issue One, we’re building bipartisan power to strengthen the foundations of American democracy — because fixing our broken political system starts with all of us. Working to uphold the rule of law, protect our institutions, and keep power where it belongs — in a government of, by, and for the people. Learn about the related work of our National Council on Election Integrity and our Faces of Democracy campaign. Issue One is at the forefront of bipartisan reform, working with over 200 former members of Congress and political appointees, technologists, and election officials from across the political spectrum. ReFormers Caucus   Faces of Democracy   Council for Responsible Social Media   The Council for American Democracy', 'Issue One is an American nonprofit organization that seeks to reduce the role of money in politics. It aims to increase public awareness of what it views as', 'Define Item Description. the information presented in this column indicates the specific item that LPHA is authorized to acquire.', 'Note: The Item Description belongs to the item and will remain with it even when moved between boards or converted to a subitem or vice versa.', 'Hydraulic systems are vital to modern aviation, providing the power needed for essential aircraft operations such as landing gear, flight control surfaces, and braking systems. By the 1930s, hydraulic systems were integrated into military aircraft, providing power to retract landing gear and operate control surfaces. These characteristics make hydraulic systems the preferred solution for powering key aircraft functions such as **landing gear extension/retraction, flight controls, spoilers, and brakes**. * **Operation**: The standby system is automatically or manually activated, providing hydraulic power to ensure the safety of the aircraft during critical moments, such as landing. * Hydraulic systems operate at very high pressures, typically around **3000 psi** in the Boeing 737, providing the force needed to control heavy aircraft components with precision.', 'Hydraulic Retraction system\u200b\u200b A hydraulic system for retracting and extending a landing gear normally takes its power from engine driven pumps, alternative', 'Fluid Accumulation: Puddles, drips, or wet spots around your hydraulic equipment are the m ...
# {'generate': {'draft': '# **Structured Troubleshooting Document**  \n## **Hydraulic‑Leak Issue – Landing‑Gear\u202fB**  \n*(Applicable to all aircraft types that use a dual‑gear hydraulic system; adjust OEM references as required.)*  \n\n---\n\n## 1. Purpose & Scope  \n\n| Item | Description |\n|------|-------------|\n| **Purpose** | Provide a **standardised, repeatable** method for diagnosing, repairing and documenting a hydraulic‑leak on **Landing‑Gear\u202fB**. The goal is to minimise aircraft ground time, ensure safety, and satisfy regulatory and OEM requirements. |\n| **Scope** | • Symptom: visible or measurable hydraulic fluid loss originating from Landing‑Gear\u202fB.<br>• Excludes non‑hydraulic gear failures (actuator loss‑of‑motion, steering malfunctions, brake‑system faults, etc.). |\n| **Applicability** | Maintenance technicians, inspection staff, quality‑assurance personnel, and engineering support. |\n| **Effective Date** | 22\u202fOct\u202f2025 (review every 12\u202fmonths or when a new Service Bulletin is issued). |\n\n---\n\n## 2. Background  \n\n| Topic | Key Points |\n|-------|------------|\n| **Landing‑Gear\u202fB Position & Function** | - Typically the **right main gear** on a twin‑engine transport or the **aft gear** on a trijet.<br>- Provides **support on touchdown**, **retraction/extension** via the hydraulic system, and houses **Weight‑On‑Wheels (WOW)** sensors. |\n| **Hydraulic System Characteristics** | - **Pressure range:** 3000–3500\u202fpsi (≈\u202f210–240\u202fbar) for most transport aircraft.<br>- **Fluid type:** Phosphate‑ester (e.g., MIL‑H‑5606) or synthetic (e.g., HyJet). |\n| **Implications of a Leak** | - **Gear‑cycle degradation:** Incomplete extension/retraction, possible “gear‑up” on landing.<br>- **Loss of braking & WOW data** – compromised ground handling.<br>- **Safety hazards:** Fluid spray onto hot components → fire risk; environmental contamination. |\n| **Regulatory Framework** | - **FAR\u202fPart\u202f43/91**, **EASA Part‑M**, **ATA\u202f32 – Hydraulic Power**.<br>- OEM Maintenance Manual (e.g., B‑737‑800 MM, Ch‑32‑20).<br>- Company SOPs for **Leak Reporting**, **Hazardous‑Material Handling**, and **Airworthiness Release**. |\n\n---\n\n## 3. Core Principles of the Troubleshooting Approach  \n\n1. **Consistency** – Identical steps for all technicians, regardless of location or shift.  \n2. **Traceability** – Every action logged; enables audits and root‑cause verification.  \n3. **Efficiency** – Targeted diagnostics avoid unnecessary part removal and reduce **Mean Time To Repair (MTTR)**.  \n4. **Risk Mitigation** – Safety checks embedded at each phase (LOTO, PPE, fire‑suppression).  \n\n---\n\n## 4. Document Structure  \n\n| Component | What It Contains | Why It Matters |\n|-----------|-----------------|----------------|\n| **4.1 Safety Precautions** | PPE, grounding, fire‑extinguishers, spill containment, LOTO procedures. | Protects personnel and prevents secondary damage. |\n| **4.2 Symptom Description** | Leak location (gear bay, hose, actuator), rate (drips/min), fluid color/odor, operating conditions. | Provides a clear baseline for diagnosis. |\n| **4.3 Possible Causes** | Fault‑tree/ cause‑effect matrix (seal failure, hose abrasion, over‑pressure, valve malfunction, contamination). | Guides logical elimination of suspects. |\n| **4.4 Required Tools & Equipment** | calibrated pressure gauge, UV dye kit, borescope, leak‑detecting spray, torque wrench, clean rags, containment trays. | Guarantees technicians have the right resources. |\n| **4.5 Step‑by‑Step Procedure** | Sequential actions, decision points, “go/no‑go” criteria, verification tests. | Provides a repeatable workflow. |\n| **4.6 Verification & Test** | Post‑repair gear cycles, pressure hold test, leak re‑inspection, sensor checks. | Confirms successful repair. |\n| **4.7 Documentation & Reporting** | Discrepancy form, log‑book entry, parts list, ASRS/TSB reporting if required. | Meets regulatory and company record‑k ...

# %%
from helper import ewriter, writer_gui
MultiAgent = ewriter()
app = writer_gui(MultiAgent.graph)
app.launch(share=True)
# Out:
# /home/vcap/app/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'genai-proxy.sys.tas-ndc.kuhn-labs.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# * Running on local URL:  http://0.0.0.0:7861
# * Running on public URL: https://80622136ee497df5e5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://80622136ee497df5e5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
app.graph.get_graph().print_ascii()
# Out:
#                      +-----------+
#                      | __start__ |
#                      +-----------+
#                             *
#                             *
#                             *
#                       +---------+
#                       | planner |
#                       +---------+
#                             *
#                             *
#                             *
#                    +---------------+
#                    | research_plan |
#                    +---------------+
#                             *
#                             *
#                             *
#                       +----------+
#                       | generate |
#                    ...+----------+***
#                ....         .        ****
#            ....             .            ****
#          ..                 .                ****
# +---------+           +---------+                **
# | __end__ |           | reflect |               **
# +---------+           +---------+             **
#                                 ***         **
#                                    *      **
#                                     **   *
#                             +-------------------+
#                             | research_critique |
#                             +-------------------+
